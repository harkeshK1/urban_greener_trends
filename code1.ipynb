# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the statue image
image = cv2.imread("statue.jpg")

# Convert to HSV color space
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# Define green color range in HSV
lower_green = np.array([35, 40, 40])
upper_green = np.array([85, 255, 255])

# Create a mask for green areas
mask = cv2.inRange(hsv, lower_green, upper_green)

# Load NDVI value (between 0 and 1)
NDVI_value = 0.7  # Change this dynamically

# Modify green intensity based on NDVI
factor = NDVI_value  
image[np.where(mask == 255)] = image[np.where(mask == 255)] * factor

# Convert BGR to RGB for correct color display in Jupyter
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the modified image using Matplotlib
plt.figure(figsize=(10, 6))
plt.imshow(image_rgb)
plt.axis("off")
plt.title("Modified Statue Image with Adjusted Greenery")
plt.show()

# Save the modified image
cv2.imwrite("modified_statue.jpg", image)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import cv2
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/39.5 MB ? eta -:--:--
#     --------------------------------------- 0.5/39.5 MB 1.1 MB/s eta 0:00:35
#     --------------------------------------- 0.8/39.5 MB 1.2 MB/s eta 0:00:34
#    - -------------------------------------- 1.0/39.5 MB 1.2 MB/s eta 0:00:33
#    - -------------------------------------- 1.3/39.5 MB 1.2 MB/s eta 0:00:33
#    - -------------------------------------- 1.6/39.5 MB 1.2 MB/s eta 0:00:33
#    - -------------------------------------- 1.8/39.5 MB 1.2 MB/s eta 0:00:33
#    -- ------------------------------------- 2.1/39.5 MB 1.2 MB/s eta 0:00:33
#    -- ------------------------------------- 2.4/39.5 MB 1.1 MB/s eta 0:00:33
# ...

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the statue image
image = cv2.imread("statue.jpg")

# Convert to HSV color space
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# Define green color range in HSV
lower_green = np.array([35, 40, 40])
upper_green = np.array([85, 255, 255])

# Create a mask for green areas
mask = cv2.inRange(hsv, lower_green, upper_green)

# Load NDVI value (between 0 and 1)
NDVI_value = 0.7  # Change this dynamically

# Modify green intensity based on NDVI
factor = NDVI_value  
image[np.where(mask == 255)] = image[np.where(mask == 255)] * factor

# Convert BGR to RGB for correct color display in Jupyter
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the modified image using Matplotlib
plt.figure(figsize=(10, 6))
plt.imshow(image_rgb)
plt.axis("off")
plt.title("Modified Statue Image with Adjusted Greenery")
plt.show()

# Save the modified image
cv2.imwrite("modified_statue.jpg", image)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 9
#       6 image = cv2.imread("statue.jpg")
#       8 # Convert to HSV color space
# ----> 9 hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
#      11 # Define green color range in HSV
#      12 lower_green = np.array([35, 40, 40])
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image using the full path
image_path = r"C:\maps\chennaimap.png"  # Use raw string to avoid path issues
image = cv2.imread(image_path)

# Check if the image was loaded correctly
if image is None:
    print("Error: Could not load image. Check the file path!")
else:
    print("Image loaded successfully!")

    # Convert to HSV color space
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # Define green color range in HSV
    lower_green = np.array([35, 40, 40])
    upper_green = np.array([85, 255, 255])

    # Create a mask for green areas
    mask = cv2.inRange(hsv, lower_green, upper_green)

    # Load NDVI value (between 0 and 1)
    NDVI_value = 0.7  # Adjust this value dynamically

    # Modify green intensity based on NDVI
    factor = NDVI_value  
    image[np.where(mask == 255)] = image[np.where(mask == 255)] * factor

    # Convert BGR to RGB for correct color display in Jupyter
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Display the modified image using Matplotlib
    plt.figure(figsize=(10, 6))
    plt.imshow(image_rgb)
    plt.axis("off")
    plt.title("Modified Chennai Map with Adjusted Greenery")
    plt.show()

    # Save the modified image
    output_path = r"C:\maps\modified_chennaimap.png"
    cv2.imwrite(output_path, image)
    print(f"Modified image saved at: {output_path}")
# Out:
# Image loaded successfully!
# Modified image saved at: C:\maps\modified_chennaimap.png

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image_path = r"C:\maps\chennaimap.png"
image = cv2.imread(image_path)

# Check if the image loaded correctly
if image is None:
    print("Error: Could not load image. Check the file path!")
else:
    print("Image loaded successfully!")

    # Convert to HSV color space
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # Define green color range in HSV
    lower_green = np.array([35, 40, 40])
    upper_green = np.array([85, 255, 255])

    # Create a mask for green areas
    mask = cv2.inRange(hsv, lower_green, upper_green)

    # Load NDVI value (between 0 and 1)
    NDVI_value = 0.7  # Adjust this value dynamically

    # Adjust only the green channel while keeping the original color balance
    image_adjusted = image.copy()
    image_adjusted[:, :, 1] = cv2.addWeighted(image[:, :, 1], 1 + (NDVI_value - 0.5), 0, 0, 0)

    # Apply the mask to keep only the modified green areas
    image[mask == 255] = image_adjusted[mask == 255]

    # Convert BGR to RGB for correct display in Jupyter
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Display the modified image using Matplotlib
    plt.figure(figsize=(10, 6))
    plt.imshow(image_rgb)
    plt.axis("off")
    plt.title("Modified Chennai Map with Corrected Greenery")
    plt.show()

    # Save the modified image
    output_path = r"C:\maps\modified_chennaimap.png"
    cv2.imwrite(output_path, image)
    print(f"Modified image saved at: {output_path}")
# Out:
# Image loaded successfully!
# Modified image saved at: C:\maps\modified_chennaimap.png

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image_path = r"C:\maps\chennaimap.png"
image = cv2.imread(image_path)

# Check if the image loaded correctly
if image is None:
    print("Error: Could not load image. Check the file path!")
else:
    print("Image loaded successfully!")

    # Convert to HSV color space
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # Define green color range in HSV
    lower_green = np.array([35, 40, 40])  # Lower bound of green
    upper_green = np.array([85, 255, 255])  # Upper bound of green

    # Create a mask for green areas
    mask = cv2.inRange(hsv, lower_green, upper_green)

    # Extract green pixels from the original image
    green_pixels = image[mask == 255]

    # Compute the average green shade in the image
    if len(green_pixels) > 0:
        avg_green = np.mean(green_pixels[:, 1])  # Extract the mean of the green channel
    else:
        avg_green = 128  # Default green if no green is found

    # Load NDVI value (between 0 and 1)
    NDVI_value = 0.7  # Adjust this dynamically

    # Adjust only the green areas based on NDVI
    image_adjusted = image.copy()

    # Increase or decrease the green intensity proportionally
    factor = 1 + (NDVI_value - 0.5)  # Adjust green based on NDVI, centered around 1
    image_adjusted[:, :, 1] = np.clip(image[:, :, 1] * factor, 0, avg_green)  # Scale green within limits

    # Apply the mask to keep only modified green areas
    image[mask == 255] = image_adjusted[mask == 255]

    # Convert BGR to RGB for correct display in Jupyter
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Display the modified image
    plt.figure(figsize=(10, 6))
    plt.imshow(image_rgb)
    plt.axis("off")
    plt.title("Modified Chennai Map with Natural Greenery Adjustments")
    plt.show()

    # Save the modified image
    output_path = r"C:\maps\modified_chennaimap.png"
    cv2.imwrite(output_path, image)
    print(f"Modified image saved at: {output_path}")
# Out:
# Image loaded successfully!
# Modified image saved at: C:\maps\modified_chennaimap.png

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the original image
image_path = r"C:\maps\chennaimap.png"
original_image = cv2.imread(image_path)

# Check if the image loaded correctly
if original_image is None:
    print("Error: Could not load image. Check the file path!")
else:
    print("Image loaded successfully!")

    # Convert to HSV color space
    hsv = cv2.cvtColor(original_image, cv2.COLOR_BGR2HSV)

    # Define green color range in HSV
    lower_green = np.array([35, 40, 40])
    upper_green = np.array([85, 255, 255])

    # Create a mask for green areas
    mask = cv2.inRange(hsv, lower_green, upper_green)

    # Extract green pixels from the original image
    green_pixels = original_image[mask == 255]

    # Compute the average green intensity in the image
    if len(green_pixels) > 0:
        avg_green = np.mean(green_pixels[:, 1])
    else:
        avg_green = 128  # Default green level if no green found

    # List of 10 NDVI values provided
    ndvi_values = [0.0840, 0.0746, 0.0717, 0.0676, 0.0648, 
                   0.0623, 0.0602, 0.0585, 0.0571, 0.0559]

    # Generate maps for each NDVI value
    for i, NDVI_value in enumerate(ndvi_values):
        # Copy the original image
        image = original_image.copy()

        # Adjust green intensity based on NDVI
        factor = 1 + (NDVI_value - 0.5)  # Scale factor centered around 1
        image_adjusted = image.copy()
        image_adjusted[:, :, 1] = np.clip(image[:, :, 1] * factor, 0, avg_green)

        # Apply the mask to keep only modified green areas
        image[mask == 255] = image_adjusted[mask == 255]

        # Save the modified image
        output_path = rf"C:\maps\modified_chennaimap_{2025 + i}.png"
        cv2.imwrite(output_path, image)
        print(f"Saved: {output_path}")

    print("✅ All maps generated successfully!")
# Out:
# Image loaded successfully!
# Saved: C:\maps\modified_chennaimap_2025.png
# Saved: C:\maps\modified_chennaimap_2026.png
# Saved: C:\maps\modified_chennaimap_2027.png
# Saved: C:\maps\modified_chennaimap_2028.png
# Saved: C:\maps\modified_chennaimap_2029.png
# Saved: C:\maps\modified_chennaimap_2030.png
# Saved: C:\maps\modified_chennaimap_2031.png
# Saved: C:\maps\modified_chennaimap_2032.png
# Saved: C:\maps\modified_chennaimap_2033.png
# Saved: C:\maps\modified_chennaimap_2034.png
# ✅ All maps generated successfully!

# %%
import cv2
import numpy as np
import os

# Load the base image
image_path = "C:/maps/chennaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV for better color manipulation
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define the green color range (based on your base image)
lower_green = np.array([35, 40, 40])  # Adjust if necessary
upper_green = np.array([85, 255, 255])

# Create a mask to detect green areas
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# NDVI values for each map
ndvi_values = [0.0840, 0.0746, 0.0717, 0.0676, 0.0648, 0.0623, 0.0602, 0.0585, 0.0571, 0.0559]

# Output directory
output_dir = "C:/maps/generated_maps"
os.makedirs(output_dir, exist_ok=True)

# Generate maps with decreasing green intensity
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()
    
    # Reduce green intensity based on NDVI
    factor = ndvi / max(ndvi_values)  # Normalize to max NDVI
    adjusted_hsv[:, :, 1] = np.where(green_mask > 0, adjusted_hsv[:, :, 1] * factor, adjusted_hsv[:, :, 1])
    
    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)
    
    # Save the image
    output_path = os.path.join(output_dir, f"ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("All maps generated successfully!")
# Out:
# Saved: C:/maps/generated_maps\ndvi_map_1.png
# Saved: C:/maps/generated_maps\ndvi_map_2.png
# Saved: C:/maps/generated_maps\ndvi_map_3.png
# Saved: C:/maps/generated_maps\ndvi_map_4.png
# Saved: C:/maps/generated_maps\ndvi_map_5.png
# Saved: C:/maps/generated_maps\ndvi_map_6.png
# Saved: C:/maps/generated_maps\ndvi_map_7.png
# Saved: C:/maps/generated_maps\ndvi_map_8.png
# Saved: C:/maps/generated_maps\ndvi_map_9.png
# Saved: C:/maps/generated_maps\ndvi_map_10.png
# All maps generated successfully!

# %%
import cv2
import numpy as np
import os

# Load the base image
image_path = r"C:\maps\chennaimap.png"
base_image = cv2.imread(image_path)

# Check if the image loaded correctly
if base_image is None:
    print("Error: Could not load the image. Check the file path!")
    exit()

# Convert to HSV color space
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define green color range in HSV
lower_green = np.array([35, 40, 40])
upper_green = np.array([85, 255, 255])

# Create a mask to detect green areas
mask = cv2.inRange(hsv, lower_green, upper_green)

# Store green pixel positions
green_pixels = np.column_stack(np.where(mask == 255))

# NDVI values (for 10 stages)
ndvi_values = [0.0840, 0.0746, 0.0717, 0.0676, 0.0648,
               0.0623, 0.0602, 0.0585, 0.0571, 0.0559]

# Normalize NDVI to [0, 1] to use in transformations
min_ndvi = min(ndvi_values)
max_ndvi = max(ndvi_values)
normalized_ndvi = [(ndvi - min_ndvi) / (max_ndvi - min_ndvi) for ndvi in ndvi_values]

# Create output folder
output_dir = r"C:\maps\generated_maps"
os.makedirs(output_dir, exist_ok=True)

# Generate maps with progressive green reduction
for i, ndvi in enumerate(normalized_ndvi):
    # Copy the original image
    modified_image = base_image.copy()
    
    # Adjust green intensity based on NDVI
    green_scale_factor = 1 - (1 - ndvi) * 0.5  # Reduce green gradually
    modified_image[:, :, 1] = np.clip(modified_image[:, :, 1] * green_scale_factor, 0, 255)

    # Gradually remove green areas (randomly remove pixels over time)
    removal_fraction = (1 - ndvi) * 0.6  # Higher NDVI = fewer removals, lower NDVI = more removals
    num_pixels_to_remove = int(len(green_pixels) * removal_fraction)

    if num_pixels_to_remove > 0:
        removed_indices = np.random.choice(len(green_pixels), num_pixels_to_remove, replace=False)
        for idx in removed_indices:
            y, x = green_pixels[idx]
            modified_image[y, x] = [180, 180, 180]  # Replace with dry/barren land color

    # Save the modified image
    output_path = os.path.join(output_dir, f"chennaimap_{2025 + i}.png")
    cv2.imwrite(output_path, modified_image)
    print(f"Saved: {output_path}")

print("✅ 10 maps generated with gradual green reduction!")
# Out:
# Saved: C:\maps\generated_maps\chennaimap_2025.png
# Saved: C:\maps\generated_maps\chennaimap_2026.png
# Saved: C:\maps\generated_maps\chennaimap_2027.png
# Saved: C:\maps\generated_maps\chennaimap_2028.png
# Saved: C:\maps\generated_maps\chennaimap_2029.png
# Saved: C:\maps\generated_maps\chennaimap_2030.png
# Saved: C:\maps\generated_maps\chennaimap_2031.png
# Saved: C:\maps\generated_maps\chennaimap_2032.png
# Saved: C:\maps\generated_maps\chennaimap_2033.png
# Saved: C:\maps\generated_maps\chennaimap_2034.png
# ✅ 10 maps generated with gradual green reduction!

# %%
import cv2
import numpy as np
import os

# Load the base image
image_path = "C:/maps/chennaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV for better color manipulation
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define the green color range (based on your base image)
lower_green = np.array([35, 40, 40])  # Adjust if necessary
upper_green = np.array([85, 255, 255])

# Create a mask to detect green areas
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# Get coordinates of green pixels
green_pixels = np.column_stack(np.where(green_mask > 0))

# NDVI values for each map
ndvi_values = [0.0840, 0.0746, 0.0717, 0.0676, 0.0648, 0.0623, 0.0602, 0.0585, 0.0571, 0.0559]

# Output directory
output_dir = "C:/maps/generated_maps"
os.makedirs(output_dir, exist_ok=True)

# Generate maps with decreasing green intensity & disappearing green pixels
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()
    
    # Reduce green intensity based on NDVI
    factor = ndvi / max(ndvi_values)  # Normalize to max NDVI
    adjusted_hsv[:, :, 1] = np.where(green_mask > 0, adjusted_hsv[:, :, 1] * factor, adjusted_hsv[:, :, 1])
    
    # Gradually remove green pixels by replacing a fraction with dry land color
    removal_fraction = (i + 1) / len(ndvi_values) * 0.5  # Gradual removal over 10 stages (max 50%)
    num_pixels_to_remove = int(len(green_pixels) * removal_fraction)

    if num_pixels_to_remove > 0:
        removed_indices = np.random.choice(len(green_pixels), num_pixels_to_remove, replace=False)
        for idx in removed_indices:
            y, x = green_pixels[idx]
            adjusted_hsv[y, x] = [20, 50, 120]  # Dry land color in HSV (brownish)

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)
    
    # Save the image
    output_path = os.path.join(output_dir, f"ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ All maps generated successfully!")
# Out:
# Saved: C:/maps/generated_maps\ndvi_map_1.png
# Saved: C:/maps/generated_maps\ndvi_map_2.png
# Saved: C:/maps/generated_maps\ndvi_map_3.png
# Saved: C:/maps/generated_maps\ndvi_map_4.png
# Saved: C:/maps/generated_maps\ndvi_map_5.png
# Saved: C:/maps/generated_maps\ndvi_map_6.png
# Saved: C:/maps/generated_maps\ndvi_map_7.png
# Saved: C:/maps/generated_maps\ndvi_map_8.png
# Saved: C:/maps/generated_maps\ndvi_map_9.png
# Saved: C:/maps/generated_maps\ndvi_map_10.png
# ✅ All maps generated successfully!

# %%
import cv2
import numpy as np
import os

# Load the base image
image_path = "C:/maps/chennaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV for better color manipulation
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define the green color range (based on your base image)
lower_green = np.array([35, 40, 40])  # Adjust if necessary
upper_green = np.array([85, 255, 255])

# Create a mask to detect green areas
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# Get coordinates of green pixels
green_pixels = np.column_stack(np.where(green_mask > 0))

# NDVI values for each map
ndvi_values = [0.0840, 0.0746, 0.0717, 0.0676, 0.0648, 0.0623, 0.0602, 0.0585, 0.0571, 0.0559]

# Output directory
output_dir = "C:/maps/generated_maps"
os.makedirs(output_dir, exist_ok=True)

# Generate maps with decreasing green intensity & slight green pixel removal
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()
    
    # Reduce green intensity based on NDVI
    factor = ndvi / max(ndvi_values)  # Normalize to max NDVI
    adjusted_hsv[:, :, 1] = np.where(green_mask > 0, adjusted_hsv[:, :, 1] * factor, adjusted_hsv[:, :, 1])
    
    # Gradually remove a small percentage of green pixels
    removal_fraction = (i + 1) / len(ndvi_values) * 0.2  # Max 20% of green pixels removed at stage 10
    num_pixels_to_remove = int(len(green_pixels) * removal_fraction)

    if num_pixels_to_remove > 0:
        removed_indices = np.random.choice(len(green_pixels), num_pixels_to_remove, replace=False)
        for idx in removed_indices:
            y, x = green_pixels[idx]
            adjusted_hsv[y, x] = [25, 40, 170]  # Light barren color (similar to surroundings)

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)
    
    # Save the image
    output_path = os.path.join(output_dir, f"ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ All maps generated successfully!")
# Out:
# Saved: C:/maps/generated_maps\ndvi_map_1.png
# Saved: C:/maps/generated_maps\ndvi_map_2.png
# Saved: C:/maps/generated_maps\ndvi_map_3.png
# Saved: C:/maps/generated_maps\ndvi_map_4.png
# Saved: C:/maps/generated_maps\ndvi_map_5.png
# Saved: C:/maps/generated_maps\ndvi_map_6.png
# Saved: C:/maps/generated_maps\ndvi_map_7.png
# Saved: C:/maps/generated_maps\ndvi_map_8.png
# Saved: C:/maps/generated_maps\ndvi_map_9.png
# Saved: C:/maps/generated_maps\ndvi_map_10.png
# ✅ All maps generated successfully!

# %%
import cv2
import numpy as np
import os

# Load the base image
image_path = "C:/maps/chennaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV for better color manipulation
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define the green color range (based on your base image)
lower_green = np.array([35, 40, 40])  
upper_green = np.array([85, 255, 255])

# Create a mask to detect green areas
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# NDVI values for each map
ndvi_values = [0.0840, 0.0746, 0.0717, 0.0676, 0.0648, 0.0623, 0.0602, 0.0585, 0.0571, 0.0559]

# Output directory
output_dir = "C:/maps/generated_maps"
os.makedirs(output_dir, exist_ok=True)

# Kernel for morphological operations (to remove in clusters)
kernel = np.ones((3, 3), np.uint8)  

# Generate maps with decreasing green intensity & natural green pixel removal
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    # Reduce green intensity based on NDVI
    factor = ndvi / max(ndvi_values)  
    adjusted_hsv[:, :, 1] = np.where(green_mask > 0, adjusted_hsv[:, :, 1] * factor, adjusted_hsv[:, :, 1])

    # Gradually remove green pixels in clusters
    removal_fraction = (i + 1) / len(ndvi_values) * 0.2  
    remove_mask = green_mask.copy()

    # Erode (to thin green regions) and then dilate (to ensure natural clustering)
    remove_mask = cv2.erode(remove_mask, kernel, iterations=1)
    remove_mask = cv2.dilate(remove_mask, kernel, iterations=1)

    # Select pixels to replace with barren color
    barren_color = np.array([25, 40, 170])  
    adjusted_hsv[:, :, 0] = np.where(remove_mask > 0, barren_color[0], adjusted_hsv[:, :, 0])
    adjusted_hsv[:, :, 1] = np.where(remove_mask > 0, barren_color[1], adjusted_hsv[:, :, 1])
    adjusted_hsv[:, :, 2] = np.where(remove_mask > 0, barren_color[2], adjusted_hsv[:, :, 2])

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save the image
    output_path = os.path.join(output_dir, f"ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ All maps generated successfully!")
# Out:
# Saved: C:/maps/generated_maps\ndvi_map_1.png
# Saved: C:/maps/generated_maps\ndvi_map_2.png
# Saved: C:/maps/generated_maps\ndvi_map_3.png
# Saved: C:/maps/generated_maps\ndvi_map_4.png
# Saved: C:/maps/generated_maps\ndvi_map_5.png
# Saved: C:/maps/generated_maps\ndvi_map_6.png
# Saved: C:/maps/generated_maps\ndvi_map_7.png
# Saved: C:/maps/generated_maps\ndvi_map_8.png
# Saved: C:/maps/generated_maps\ndvi_map_9.png
# Saved: C:/maps/generated_maps\ndvi_map_10.png
# ✅ All maps generated successfully!

# %%
import cv2
import numpy as np
import os

# Load the base image
image_path = "C:/maps/chennaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV for better color manipulation
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define the green color range (based on your base image)
lower_green = np.array([35, 40, 40])  
upper_green = np.array([85, 255, 255])

# Create a mask to detect green areas
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# Get coordinates of green pixels
green_pixels = np.column_stack(np.where(green_mask > 0))

# NDVI values for each map
ndvi_values = [0.0840, 0.0746, 0.0717, 0.0676, 0.0648, 0.0623, 0.0602, 0.0585, 0.0571, 0.0559]

# Output directory
output_dir = "C:/maps/generated_maps"
os.makedirs(output_dir, exist_ok=True)

# Generate maps with decreasing green intensity & natural green pixel removal
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    # Reduce green intensity based on NDVI
    factor = ndvi / max(ndvi_values)  
    adjusted_hsv[:, :, 1] = np.where(green_mask > 0, adjusted_hsv[:, :, 1] * factor, adjusted_hsv[:, :, 1])

    # Gradually remove green pixels **smoothly**
    removal_fraction = (i + 1) / len(ndvi_values) * 0.2  # Max 20% of green pixels removed at stage 10
    num_pixels_to_remove = int(len(green_pixels) * removal_fraction)

    if num_pixels_to_remove > 0:
        removed_indices = np.random.choice(len(green_pixels), num_pixels_to_remove, replace=False)
        for idx in removed_indices:
            y, x = green_pixels[idx]
            # Instead of making it brown, blend it into its surroundings
            adjusted_hsv[y, x] = hsv[y, x] * 0.8 + np.array([25, 50, 100]) * 0.2  # Very subtle barren color

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save the image
    output_path = os.path.join(output_dir, f"ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ All maps generated successfully!")
# Out:
# Saved: C:/maps/generated_maps\ndvi_map_1.png
# Saved: C:/maps/generated_maps\ndvi_map_2.png
# Saved: C:/maps/generated_maps\ndvi_map_3.png
# Saved: C:/maps/generated_maps\ndvi_map_4.png
# Saved: C:/maps/generated_maps\ndvi_map_5.png
# Saved: C:/maps/generated_maps\ndvi_map_6.png
# Saved: C:/maps/generated_maps\ndvi_map_7.png
# Saved: C:/maps/generated_maps\ndvi_map_8.png
# Saved: C:/maps/generated_maps\ndvi_map_9.png
# Saved: C:/maps/generated_maps\ndvi_map_10.png
# ✅ All maps generated successfully!

# %%
import cv2
import numpy as np
import os

# Load the base image
image_path = "C:/maps/chennaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV for better color manipulation
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define the green color range (based on your base image)
lower_green = np.array([35, 40, 40])  
upper_green = np.array([85, 255, 255])

# Create a mask to detect green areas
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# Get coordinates of green pixels
green_pixels = np.column_stack(np.where(green_mask > 0))

# NDVI values for each map
ndvi_values = [0.0840, 0.0746, 0.0717, 0.0676, 0.0648, 0.0623, 0.0602, 0.0585, 0.0571, 0.0559]

# Output directory
output_dir = "C:/maps/generated_maps"
os.makedirs(output_dir, exist_ok=True)

# Generate maps with slightly increased vegetation loss
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    # Reduce green intensity based on NDVI
    factor = ndvi / max(ndvi_values)  
    adjusted_hsv[:, :, 1] = np.where(green_mask > 0, adjusted_hsv[:, :, 1] * factor, adjusted_hsv[:, :, 1])

    # **Increase green loss slightly**
    removal_fraction = ((i + 1) / len(ndvi_values) * 0.3)  # Increased from 0.2 to 0.3 (max 30% loss at stage 10)
    num_pixels_to_remove = int(len(green_pixels) * removal_fraction)

    if num_pixels_to_remove > 0:
        removed_indices = np.random.choice(len(green_pixels), num_pixels_to_remove, replace=False)
        for idx in removed_indices:
            y, x = green_pixels[idx]
            # Blend the removed pixels with a slightly stronger barren land color
            adjusted_hsv[y, x] = hsv[y, x] * 0.7 + np.array([25, 60, 120]) * 0.3  # Slightly more barren

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save the image
    output_path = os.path.join(output_dir, f"ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ All maps generated with slightly increased vegetation loss!")
# Out:
# Saved: C:/maps/generated_maps\ndvi_map_1.png
# Saved: C:/maps/generated_maps\ndvi_map_2.png
# Saved: C:/maps/generated_maps\ndvi_map_3.png
# Saved: C:/maps/generated_maps\ndvi_map_4.png
# Saved: C:/maps/generated_maps\ndvi_map_5.png
# Saved: C:/maps/generated_maps\ndvi_map_6.png
# Saved: C:/maps/generated_maps\ndvi_map_7.png
# Saved: C:/maps/generated_maps\ndvi_map_8.png
# Saved: C:/maps/generated_maps\ndvi_map_9.png
# Saved: C:/maps/generated_maps\ndvi_map_10.png
# ✅ All maps generated with slightly increased vegetation loss!

# %%
import cv2
import numpy as np
import os

# Load the base image
image_path = "C:/maps/chennaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV for better color manipulation
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define the green color range (based on your base image)
lower_green = np.array([35, 40, 40])  
upper_green = np.array([85, 255, 255])

# Create a mask to detect green areas
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# Get coordinates of green pixels
green_pixels = np.column_stack(np.where(green_mask > 0))

# NDVI values for each map
ndvi_values = [0.0840, 0.0746, 0.0717, 0.0676, 0.0648, 0.0623, 0.0602, 0.0585, 0.0571, 0.0559]

# Output directory
output_dir = "C:/maps/generated_maps"
os.makedirs(output_dir, exist_ok=True)

# Generate maps with **slightly more** vegetation loss
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    # Reduce green intensity based on NDVI
    factor = ndvi / max(ndvi_values)  
    adjusted_hsv[:, :, 1] = np.where(green_mask > 0, adjusted_hsv[:, :, 1] * factor, adjusted_hsv[:, :, 1])

    # **Increase green loss a bit more**
    removal_fraction = ((i + 1) / len(ndvi_values) * 0.4)  # Max 40% loss at stage 10
    num_pixels_to_remove = int(len(green_pixels) * removal_fraction)

    if num_pixels_to_remove > 0:
        removed_indices = np.random.choice(len(green_pixels), num_pixels_to_remove, replace=False)
        for idx in removed_indices:
            y, x = green_pixels[idx]
            # Blend the removed pixels with a more noticeable barren land color
            adjusted_hsv[y, x] = hsv[y, x] * 0.6 + np.array([25, 70, 140]) * 0.4  # More barren blending

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save the image
    output_path = os.path.join(output_dir, f"ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ All maps generated with **more visible** vegetation loss!")
# Out:
# Saved: C:/maps/generated_maps\ndvi_map_1.png
# Saved: C:/maps/generated_maps\ndvi_map_2.png
# Saved: C:/maps/generated_maps\ndvi_map_3.png
# Saved: C:/maps/generated_maps\ndvi_map_4.png
# Saved: C:/maps/generated_maps\ndvi_map_5.png
# Saved: C:/maps/generated_maps\ndvi_map_6.png
# Saved: C:/maps/generated_maps\ndvi_map_7.png
# Saved: C:/maps/generated_maps\ndvi_map_8.png
# Saved: C:/maps/generated_maps\ndvi_map_9.png
# Saved: C:/maps/generated_maps\ndvi_map_10.png
# ✅ All maps generated with **more visible** vegetation loss!

# %%
import cv2
import numpy as np
import os

# Load the base image
image_path = "C:/maps/chennaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV for better color manipulation
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define the green color range (based on your base image)
lower_green = np.array([35, 40, 40])  
upper_green = np.array([85, 255, 255])

# Create a mask to detect green areas
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# Get coordinates of green pixels
green_pixels = np.column_stack(np.where(green_mask > 0))

# NDVI values for each map
ndvi_values = [0.0840, 0.0746, 0.0717, 0.0676, 0.0648, 0.0623, 0.0602, 0.0585, 0.0571, 0.0559]

# Output directory
output_dir = "C:/maps/generated_maps"
os.makedirs(output_dir, exist_ok=True)

# Generate maps with **even more vegetation loss**
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    # Reduce green intensity based on NDVI
    factor = ndvi / max(ndvi_values)  
    adjusted_hsv[:, :, 1] = np.where(green_mask > 0, adjusted_hsv[:, :, 1] * factor, adjusted_hsv[:, :, 1])

    # **Increase green loss even more**
    removal_fraction = ((i + 1) / len(ndvi_values) * 0.5)  # Max 50% loss at stage 10
    num_pixels_to_remove = int(len(green_pixels) * removal_fraction)

    if num_pixels_to_remove > 0:
        removed_indices = np.random.choice(len(green_pixels), num_pixels_to_remove, replace=False)
        for idx in removed_indices:
            y, x = green_pixels[idx]
            # Blend the removed pixels with a more pronounced barren land color
            adjusted_hsv[y, x] = hsv[y, x] * 0.5 + np.array([30, 80, 160]) * 0.5  # Slightly stronger barren tone

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save the image
    output_path = os.path.join(output_dir, f"ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ All maps generated with **50% vegetation loss!**")
# Out:
# Saved: C:/maps/generated_maps\ndvi_map_1.png
# Saved: C:/maps/generated_maps\ndvi_map_2.png
# Saved: C:/maps/generated_maps\ndvi_map_3.png
# Saved: C:/maps/generated_maps\ndvi_map_4.png
# Saved: C:/maps/generated_maps\ndvi_map_5.png
# Saved: C:/maps/generated_maps\ndvi_map_6.png
# Saved: C:/maps/generated_maps\ndvi_map_7.png
# Saved: C:/maps/generated_maps\ndvi_map_8.png
# Saved: C:/maps/generated_maps\ndvi_map_9.png
# Saved: C:/maps/generated_maps\ndvi_map_10.png
# ✅ All maps generated with **50% vegetation loss!**

# %%
import cv2
import numpy as np
import os

# Load the base image
image_path = "C:/maps/chennaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV for better color manipulation
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define the green color range (based on your base image)
lower_green = np.array([35, 40, 40])  
upper_green = np.array([85, 255, 255])

# Create a mask to detect green areas
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# NDVI values for each map
ndvi_values = [0.0840, 0.0746, 0.0717, 0.0676, 0.0648, 0.0623, 0.0602, 0.0585, 0.0571, 0.0559]

# Output directory
output_dir = "C:/maps/generated_maps"
os.makedirs(output_dir, exist_ok=True)

# Generate maps with **smooth green loss**
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    # Reduce green intensity based on NDVI
    factor = ndvi / max(ndvi_values)  
    adjusted_hsv[:, :, 1] = np.where(green_mask > 0, adjusted_hsv[:, :, 1] * factor, adjusted_hsv[:, :, 1])

    # **Smoothly remove green areas**
    removal_fraction = ((i + 1) / len(ndvi_values) * 0.5)  # Max 50% loss at stage 10
    removal_mask = (green_mask > 0).astype(np.uint8)  # Convert to binary mask
    kernel_size = int(3 + (i * 1.5))  # Slightly increase blur size as more green disappears
    removal_mask = cv2.GaussianBlur(removal_mask * 255, (kernel_size, kernel_size), 0)  # Smooth transition

    # Reduce green where the blurred mask is active
    adjusted_hsv[:, :, 1] = np.where(removal_mask > 128, adjusted_hsv[:, :, 1] * 0.5, adjusted_hsv[:, :, 1])

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save the image
    output_path = os.path.join(output_dir, f"ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ All maps generated with **smooth green loss, no dots!**")
# Out:
# Saved: C:/maps/generated_maps\ndvi_map_1.png
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[16], line 41
#      39 removal_mask = (green_mask > 0).astype(np.uint8)  # Convert to binary mask
#      40 kernel_size = int(3 + (i * 1.5))  # Slightly increase blur size as more green disappears
# ---> 41 removal_mask = cv2.GaussianBlur(removal_mask * 255, (kernel_size, kernel_size), 0)  # Smooth transition
#      43 # Reduce green where the blurred mask is active
#      44 adjusted_hsv[:, :, 1] = np.where(removal_mask > 128, adjusted_hsv[:, :, 1] * 0.5, adjusted_hsv[:, :, 1])
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\smooth.dispatch.cpp:294: error: (-215:Assertion failed) ksize.width > 0 && ksize.width % 2 == 1 && ksize.height > 0 && ksize.height % 2 == 1 in function 'cv::createGaussianKernels'

# %%
import cv2
import numpy as np
import os

# Load the base image
image_path = "C:/maps/chennaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV for better color manipulation
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define the green color range (based on your base image)
lower_green = np.array([35, 40, 40])  
upper_green = np.array([85, 255, 255])

# Create a mask to detect green areas
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# NDVI values for each map
ndvi_values = [0.0840, 0.0746, 0.0717, 0.0676, 0.0648, 0.0623, 0.0602, 0.0585, 0.0571, 0.0559]

# Output directory
output_dir = "C:/maps/generated_maps"
os.makedirs(output_dir, exist_ok=True)

# Generate maps with **smooth green loss**
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    # Reduce green intensity based on NDVI
    factor = ndvi / max(ndvi_values)  
    adjusted_hsv[:, :, 1] = np.where(green_mask > 0, adjusted_hsv[:, :, 1] * factor, adjusted_hsv[:, :, 1])

    # **Smoothly remove green areas**
    removal_fraction = ((i + 1) / len(ndvi_values) * 0.5)  # Max 50% loss at stage 10
    removal_mask = (green_mask > 0).astype(np.uint8)  # Convert to binary mask
    kernel_size = int(3 + (i * 1.5))  # Slightly increase blur size as more green disappears
    removal_mask = cv2.GaussianBlur(removal_mask * 255, (kernel_size, kernel_size), 0)  # Smooth transition

    # Reduce green where the blurred mask is active
    adjusted_hsv[:, :, 1] = np.where(removal_mask > 128, adjusted_hsv[:, :, 1] * 0.5, adjusted_hsv[:, :, 1])

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save the image
    output_path = os.path.join(output_dir, f"ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ All maps generated with **smooth green loss, no dots!**")
# Out:
# Saved: C:/maps/generated_maps\ndvi_map_1.png
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[17], line 41
#      39 removal_mask = (green_mask > 0).astype(np.uint8)  # Convert to binary mask
#      40 kernel_size = int(3 + (i * 1.5))  # Slightly increase blur size as more green disappears
# ---> 41 removal_mask = cv2.GaussianBlur(removal_mask * 255, (kernel_size, kernel_size), 0)  # Smooth transition
#      43 # Reduce green where the blurred mask is active
#      44 adjusted_hsv[:, :, 1] = np.where(removal_mask > 128, adjusted_hsv[:, :, 1] * 0.5, adjusted_hsv[:, :, 1])
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\smooth.dispatch.cpp:294: error: (-215:Assertion failed) ksize.width > 0 && ksize.width % 2 == 1 && ksize.height > 0 && ksize.height % 2 == 1 in function 'cv::createGaussianKernels'

# %%
import cv2
import numpy as np
import os

# Load the base image
image_path = "C:/maps/chennaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV for better color manipulation
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define the green color range (based on your base image)
lower_green = np.array([35, 40, 40])  
upper_green = np.array([85, 255, 255])

# Create a mask to detect green areas
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# NDVI values for each map
ndvi_values = [0.0840, 0.0746, 0.0717, 0.0676, 0.0648, 0.0623, 0.0602, 0.0585, 0.0571, 0.0559]

# Output directory
output_dir = "C:/maps/generated_maps"
os.makedirs(output_dir, exist_ok=True)

# Generate maps with **smooth green loss**
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    # Reduce green intensity based on NDVI
    factor = ndvi / max(ndvi_values)  
    adjusted_hsv[:, :, 1] = np.where(green_mask > 0, adjusted_hsv[:, :, 1] * factor, adjusted_hsv[:, :, 1])

    # **Smoothly remove green areas**
    removal_fraction = ((i + 1) / len(ndvi_values) * 0.5)  # Max 50% loss at stage 10
    removal_mask = (green_mask > 0).astype(np.uint8)  # Convert to binary mask
    kernel_size = int(3 + (i * 1.5))  # Slightly increase blur size as more green disappears
    removal_mask = cv2.GaussianBlur(removal_mask * 255, (kernel_size, kernel_size), 0)  # Smooth transition

    # Reduce green where the blurred mask is active
    adjusted_hsv[:, :, 1] = np.where(removal_mask > 128, adjusted_hsv[:, :, 1] * 0.5, adjusted_hsv[:, :, 1])

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save the image
    output_path = os.path.join(output_dir, f"ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ All maps generated with **smooth green loss, no dots!**")
# Out:
# Saved: C:/maps/generated_maps\ndvi_map_1.png
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 41
#      39 removal_mask = (green_mask > 0).astype(np.uint8)  # Convert to binary mask
#      40 kernel_size = int(3 + (i * 1.5))  # Slightly increase blur size as more green disappears
# ---> 41 removal_mask = cv2.GaussianBlur(removal_mask * 255, (kernel_size, kernel_size), 0)  # Smooth transition
#      43 # Reduce green where the blurred mask is active
#      44 adjusted_hsv[:, :, 1] = np.where(removal_mask > 128, adjusted_hsv[:, :, 1] * 0.5, adjusted_hsv[:, :, 1])
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\smooth.dispatch.cpp:294: error: (-215:Assertion failed) ksize.width > 0 && ksize.width % 2 == 1 && ksize.height > 0 && ksize.height % 2 == 1 in function 'cv::createGaussianKernels'

# %%
import cv2
import numpy as np
import os

# Load the base image
image_path = "C:/maps/chennaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV for better color manipulation
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define the green color range (based on your base image)
lower_green = np.array([35, 40, 40])  
upper_green = np.array([85, 255, 255])

# Create a mask to detect green areas
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# NDVI values for each map
ndvi_values = [0.0840, 0.0746, 0.0717, 0.0676, 0.0648, 0.0623, 0.0602, 0.0585, 0.0571, 0.0559]

# Output directory
output_dir = "C:/maps/generated_maps"
os.makedirs(output_dir, exist_ok=True)

# Generate maps with **smooth green loss**
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    # Reduce green intensity based on NDVI
    factor = ndvi / max(ndvi_values)  
    adjusted_hsv[:, :, 1] = np.where(green_mask > 0, adjusted_hsv[:, :, 1] * factor, adjusted_hsv[:, :, 1])

    # **Smoothly remove green areas**
    removal_fraction = ((i + 1) / len(ndvi_values) * 0.5)  # Max 50% loss at stage 10
    removal_mask = (green_mask > 0).astype(np.uint8)  

    # Fix: Ensure kernel size is always odd & greater than 1
    kernel_size = max(3, int(3 + (i * 1.5)) | 1)  

    removal_mask = cv2.GaussianBlur(removal_mask * 255, (kernel_size, kernel_size), 0)  

    # Reduce green where the blurred mask is active
    adjusted_hsv[:, :, 1] = np.where(removal_mask > 128, adjusted_hsv[:, :, 1] * 0.5, adjusted_hsv[:, :, 1])

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save the image
    output_path = os.path.join(output_dir, f"ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ All maps generated successfully with **smooth green loss, no crash!**")
# Out:
# Saved: C:/maps/generated_maps\ndvi_map_1.png
# Saved: C:/maps/generated_maps\ndvi_map_2.png
# Saved: C:/maps/generated_maps\ndvi_map_3.png
# Saved: C:/maps/generated_maps\ndvi_map_4.png
# Saved: C:/maps/generated_maps\ndvi_map_5.png
# Saved: C:/maps/generated_maps\ndvi_map_6.png
# Saved: C:/maps/generated_maps\ndvi_map_7.png
# Saved: C:/maps/generated_maps\ndvi_map_8.png
# Saved: C:/maps/generated_maps\ndvi_map_9.png
# Saved: C:/maps/generated_maps\ndvi_map_10.png
# ✅ All maps generated successfully with **smooth green loss, no crash!**

# %%
import cv2
import numpy as np
import os

# Load the base image
image_path = "C:/maps/chennaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV for better color manipulation
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define the green color range (based on your base image)
lower_green = np.array([35, 40, 40])  
upper_green = np.array([85, 255, 255])

# Create a mask to detect green areas
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# Get coordinates of green pixels
green_pixels = np.column_stack(np.where(green_mask > 0))

# NDVI values for each map
ndvi_values = [0.0840, 0.0746, 0.0717, 0.0676, 0.0648, 0.0623, 0.0602, 0.0585, 0.0571, 0.0559]

# Output directory
output_dir = "C:/maps/generated_maps"
os.makedirs(output_dir, exist_ok=True)

# Generate maps with **even more vegetation loss**
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    # Reduce green intensity based on NDVI
    factor = ndvi / max(ndvi_values)  
    adjusted_hsv[:, :, 1] = np.where(green_mask > 0, adjusted_hsv[:, :, 1] * factor, adjusted_hsv[:, :, 1])

    # **Increase green loss even more**
    removal_fraction = ((i + 1) / len(ndvi_values) * 0.5)  # Max 50% loss at stage 10
    num_pixels_to_remove = int(len(green_pixels) * removal_fraction)

    if num_pixels_to_remove > 0:
        removed_indices = np.random.choice(len(green_pixels), num_pixels_to_remove, replace=False)
        for idx in removed_indices:
            y, x = green_pixels[idx]
            # Blend the removed pixels with a more pronounced barren land color
            adjusted_hsv[y, x] = hsv[y, x] * 0.5 + np.array([30, 80, 160]) * 0.5  # Slightly stronger barren tone

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save the image
    output_path = os.path.join(output_dir, f"ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ All maps generated with **50% vegetation loss!**")
# Out:
# Saved: C:/maps/generated_maps\ndvi_map_1.png
# Saved: C:/maps/generated_maps\ndvi_map_2.png
# Saved: C:/maps/generated_maps\ndvi_map_3.png
# Saved: C:/maps/generated_maps\ndvi_map_4.png
# Saved: C:/maps/generated_maps\ndvi_map_5.png
# Saved: C:/maps/generated_maps\ndvi_map_6.png
# Saved: C:/maps/generated_maps\ndvi_map_7.png
# Saved: C:/maps/generated_maps\ndvi_map_8.png
# Saved: C:/maps/generated_maps\ndvi_map_9.png
# Saved: C:/maps/generated_maps\ndvi_map_10.png
# ✅ All maps generated with **50% vegetation loss!**

# %%
import cv2
import numpy as np
import os

# Load the base image
image_path = "C:/maps/chennaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV for better color manipulation
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define the green color range (based on your base image)
lower_green = np.array([35, 40, 40])  
upper_green = np.array([85, 255, 255])

# Create a mask to detect green areas
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# Get coordinates of green pixels
green_pixels = np.column_stack(np.where(green_mask > 0))

# NDVI values for each map
ndvi_values = [0.0840, 0.0746, 0.0717, 0.0676, 0.0648, 0.0623, 0.0602, 0.0585, 0.0571, 0.0559]

# Output directory
output_dir = "C:/maps/generated_maps"
os.makedirs(output_dir, exist_ok=True)

# Generate maps with **slightly more** vegetation loss
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    # Reduce green intensity based on NDVI
    factor = ndvi / max(ndvi_values)  
    adjusted_hsv[:, :, 1] = np.where(green_mask > 0, adjusted_hsv[:, :, 1] * factor, adjusted_hsv[:, :, 1])

    # **Increase green loss a bit more**
    removal_fraction = ((i + 1) / len(ndvi_values) * 0.4)  # Max 40% loss at stage 10
    num_pixels_to_remove = int(len(green_pixels) * removal_fraction)

    if num_pixels_to_remove > 0:
        removed_indices = np.random.choice(len(green_pixels), num_pixels_to_remove, replace=False)
        for idx in removed_indices:
            y, x = green_pixels[idx]
            # Blend the removed pixels with a more noticeable barren land color
            adjusted_hsv[y, x] = hsv[y, x] * 0.6 + np.array([25, 70, 140]) * 0.4  # More barren blending

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save the image
    output_path = os.path.join(output_dir, f"ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ All maps generated with **more visible** vegetation loss!")
# Out:
# Saved: C:/maps/generated_maps\ndvi_map_1.png
# Saved: C:/maps/generated_maps\ndvi_map_2.png
# Saved: C:/maps/generated_maps\ndvi_map_3.png
# Saved: C:/maps/generated_maps\ndvi_map_4.png
# Saved: C:/maps/generated_maps\ndvi_map_5.png
# Saved: C:/maps/generated_maps\ndvi_map_6.png
# Saved: C:/maps/generated_maps\ndvi_map_7.png
# Saved: C:/maps/generated_maps\ndvi_map_8.png
# Saved: C:/maps/generated_maps\ndvi_map_9.png
# Saved: C:/maps/generated_maps\ndvi_map_10.png
# ✅ All maps generated with **more visible** vegetation loss!

# %%
import cv2
import numpy as np
import os

# Load the base image
image_path = "C:/maps/chennaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV for better color manipulation
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define the green color range (based on your base image)
lower_green = np.array([35, 40, 40])  
upper_green = np.array([85, 255, 255])

# Create a mask to detect green areas
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# Get coordinates of green pixels
green_pixels = np.column_stack(np.where(green_mask > 0))

# NDVI values for each map
ndvi_values = [0.0840, 0.0746, 0.0717, 0.0676, 0.0648, 0.0623, 0.0602, 0.0585, 0.0571, 0.0559]

# Output directory
output_dir = "C:/maps/generated_maps"
os.makedirs(output_dir, exist_ok=True)

# Generate maps with slightly increased vegetation loss
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    # Reduce green intensity based on NDVI
    factor = ndvi / max(ndvi_values)  
    adjusted_hsv[:, :, 1] = np.where(green_mask > 0, adjusted_hsv[:, :, 1] * factor, adjusted_hsv[:, :, 1])

    # **Increase green loss slightly**
    removal_fraction = ((i + 1) / len(ndvi_values) * 0.3)  # Increased from 0.2 to 0.3 (max 30% loss at stage 10)
    num_pixels_to_remove = int(len(green_pixels) * removal_fraction)

    if num_pixels_to_remove > 0:
        removed_indices = np.random.choice(len(green_pixels), num_pixels_to_remove, replace=False)
        for idx in removed_indices:
            y, x = green_pixels[idx]
            # Blend the removed pixels with a slightly stronger barren land color
            adjusted_hsv[y, x] = hsv[y, x] * 0.7 + np.array([25, 60, 120]) * 0.3  # Slightly more barren

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save the image
    output_path = os.path.join(output_dir, f"ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ All maps generated with slightly increased vegetation loss!")
# Out:
# Saved: C:/maps/generated_maps\ndvi_map_1.png
# Saved: C:/maps/generated_maps\ndvi_map_2.png
# Saved: C:/maps/generated_maps\ndvi_map_3.png
# Saved: C:/maps/generated_maps\ndvi_map_4.png
# Saved: C:/maps/generated_maps\ndvi_map_5.png
# Saved: C:/maps/generated_maps\ndvi_map_6.png
# Saved: C:/maps/generated_maps\ndvi_map_7.png
# Saved: C:/maps/generated_maps\ndvi_map_8.png
# Saved: C:/maps/generated_maps\ndvi_map_9.png
# Saved: C:/maps/generated_maps\ndvi_map_10.png
# ✅ All maps generated with slightly increased vegetation loss!

# %%
import cv2
import numpy as np
import os

# Load the base image
image_path = "C:/maps/chennaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV for better color manipulation
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define the green color range (based on your base image)
lower_green = np.array([35, 40, 40])  
upper_green = np.array([85, 255, 255])

# Create a mask to detect green areas
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# Get coordinates of green pixels
green_pixels = np.column_stack(np.where(green_mask > 0))

# NDVI values for each map
ndvi_values = [0.0840, 0.0746, 0.0717, 0.0676, 0.0648, 0.0623, 0.0602, 0.0585, 0.0571, 0.0559]

# Output directory
output_dir = "C:/maps/generated_maps"
os.makedirs(output_dir, exist_ok=True)

# **Detect large green areas**
kernel = np.ones((5, 5), np.uint8)  
large_green_mask = cv2.morphologyEx(green_mask, cv2.MORPH_CLOSE, kernel)

# Generate maps with **deforestation-focused green loss**
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    # Reduce green intensity based on NDVI
    factor = ndvi / max(ndvi_values)  
    adjusted_hsv[:, :, 1] = np.where(green_mask > 0, adjusted_hsv[:, :, 1] * factor, adjusted_hsv[:, :, 1])

    # **Increase green loss in large areas**
    removal_fraction = ((i + 1) / len(ndvi_values) * 0.3)  # Max 30% loss at stage 10
    large_green_pixels = np.column_stack(np.where(large_green_mask > 0))  
    num_pixels_to_remove = int(len(large_green_pixels) * removal_fraction)

    if num_pixels_to_remove > 0:
        removed_indices = np.random.choice(len(large_green_pixels), num_pixels_to_remove, replace=False)
        for idx in removed_indices:
            y, x = large_green_pixels[idx]
            # Replace large green areas gradually with a barren land shade
            adjusted_hsv[y, x] = hsv[y, x] * 0.6 + np.array([20, 50, 100]) * 0.4  # More barren effect

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save the image
    output_path = os.path.join(output_dir, f"ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ Maps generated with **better deforestation simulation**!")
# Out:
# Saved: C:/maps/generated_maps\ndvi_map_1.png
# Saved: C:/maps/generated_maps\ndvi_map_2.png
# Saved: C:/maps/generated_maps\ndvi_map_3.png
# Saved: C:/maps/generated_maps\ndvi_map_4.png
# Saved: C:/maps/generated_maps\ndvi_map_5.png
# Saved: C:/maps/generated_maps\ndvi_map_6.png
# Saved: C:/maps/generated_maps\ndvi_map_7.png
# Saved: C:/maps/generated_maps\ndvi_map_8.png
# Saved: C:/maps/generated_maps\ndvi_map_9.png
# Saved: C:/maps/generated_maps\ndvi_map_10.png
# ✅ Maps generated with **better deforestation simulation**!

# %%
import cv2
import numpy as np
import os

# Load the base image
image_path = "C:/maps/chennaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV for better color manipulation
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define the green color range (based on your base image)
lower_green = np.array([35, 40, 40])  
upper_green = np.array([85, 255, 255])

# Create a mask to detect green areas
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# Get coordinates of green pixels
green_pixels = np.column_stack(np.where(green_mask > 0))

# **Extend NDVI values to 20 stages (same pattern)**
ndvi_values = np.linspace(0.0840, 0.0559, 20)  # Smooth transition

# Output directory
output_dir = "C:/maps/generated_maps"
os.makedirs(output_dir, exist_ok=True)

# **Detect large green areas**
kernel = np.ones((5, 5), np.uint8)  
large_green_mask = cv2.morphologyEx(green_mask, cv2.MORPH_CLOSE, kernel)

# Generate maps with **deforestation-focused green loss**
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    # Reduce green intensity based on NDVI
    factor = ndvi / max(ndvi_values)  
    adjusted_hsv[:, :, 1] = np.where(green_mask > 0, adjusted_hsv[:, :, 1] * factor, adjusted_hsv[:, :, 1])

    # **Increase green loss in large areas**
    removal_fraction = ((i + 1) / len(ndvi_values) * 0.3)  # Max 30% loss at stage 20
    large_green_pixels = np.column_stack(np.where(large_green_mask > 0))  
    num_pixels_to_remove = int(len(large_green_pixels) * removal_fraction)

    if num_pixels_to_remove > 0:
        removed_indices = np.random.choice(len(large_green_pixels), num_pixels_to_remove, replace=False)
        for idx in removed_indices:
            y, x = large_green_pixels[idx]
            # Replace large green areas gradually with a barren land shade
            adjusted_hsv[y, x] = hsv[y, x] * 0.6 + np.array([20, 50, 100]) * 0.4  # More barren effect

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save the image
    output_path = os.path.join(output_dir, f"ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ Maps generated with **20 stages for clearer vegetation loss!**")
# Out:
# Saved: C:/maps/generated_maps\ndvi_map_1.png
# Saved: C:/maps/generated_maps\ndvi_map_2.png
# Saved: C:/maps/generated_maps\ndvi_map_3.png
# Saved: C:/maps/generated_maps\ndvi_map_4.png
# Saved: C:/maps/generated_maps\ndvi_map_5.png
# Saved: C:/maps/generated_maps\ndvi_map_6.png
# Saved: C:/maps/generated_maps\ndvi_map_7.png
# Saved: C:/maps/generated_maps\ndvi_map_8.png
# Saved: C:/maps/generated_maps\ndvi_map_9.png
# Saved: C:/maps/generated_maps\ndvi_map_10.png
# Saved: C:/maps/generated_maps\ndvi_map_11.png
# Saved: C:/maps/generated_maps\ndvi_map_12.png
# Saved: C:/maps/generated_maps\ndvi_map_13.png
# Saved: C:/maps/generated_maps\ndvi_map_14.png
# Saved: C:/maps/generated_maps\ndvi_map_15.png
# Saved: C:/maps/generated_maps\ndvi_map_16.png
# Saved: C:/maps/generated_maps\ndvi_map_17.png
# Saved: C:/maps/generated_maps\ndvi_map_18.png
# Saved: C:/maps/generated_maps\ndvi_map_19.png
# Saved: C:/maps/generated_maps\ndvi_map_20.png
# ...

# %%
import cv2
import numpy as np
import os

# Load the base image
image_path = "C:/maps/chennaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV for better color manipulation
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define the green color range (based on your base image)
lower_green = np.array([35, 40, 40])  
upper_green = np.array([85, 255, 255])

# Create a mask to detect green areas
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# Find contours (boundaries of green areas)
contours, _ = cv2.findContours(green_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# NDVI values for each map (20 stages)
ndvi_values = np.linspace(0.0840, 0.0559, 20)  # Smooth transition over 20 maps

# Output directory
output_dir = "C:/maps/generated_maps"
os.makedirs(output_dir, exist_ok=True)

# Generate maps with gradual loss of big green blobs
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    # Reduce green intensity based on NDVI
    factor = ndvi / max(ndvi_values)  
    adjusted_hsv[:, :, 1] = np.where(green_mask > 0, adjusted_hsv[:, :, 1] * factor, adjusted_hsv[:, :, 1])

    # **Shrink larger green blobs first**
    removal_fraction = ((i + 1) / len(ndvi_values) * 0.4)  # Increased to 40% over 20 stages
    num_contours_to_shrink = int(len(contours) * removal_fraction)

    if num_contours_to_shrink > 0:
        for j in range(num_contours_to_shrink):
            if j < len(contours):
                # Erode the boundary of each green region slightly
                cv2.drawContours(adjusted_hsv, contours, j, (25, 60, 120), thickness=2)  # Replace edges with barren color

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save the image
    output_path = os.path.join(output_dir, f"ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ All maps generated with progressive shrinking of big green blobs!")
# Out:
# Saved: C:/maps/generated_maps\ndvi_map_1.png
# Saved: C:/maps/generated_maps\ndvi_map_2.png
# Saved: C:/maps/generated_maps\ndvi_map_3.png
# Saved: C:/maps/generated_maps\ndvi_map_4.png
# Saved: C:/maps/generated_maps\ndvi_map_5.png
# Saved: C:/maps/generated_maps\ndvi_map_6.png
# Saved: C:/maps/generated_maps\ndvi_map_7.png
# Saved: C:/maps/generated_maps\ndvi_map_8.png
# Saved: C:/maps/generated_maps\ndvi_map_9.png
# Saved: C:/maps/generated_maps\ndvi_map_10.png
# Saved: C:/maps/generated_maps\ndvi_map_11.png
# Saved: C:/maps/generated_maps\ndvi_map_12.png
# Saved: C:/maps/generated_maps\ndvi_map_13.png
# Saved: C:/maps/generated_maps\ndvi_map_14.png
# Saved: C:/maps/generated_maps\ndvi_map_15.png
# Saved: C:/maps/generated_maps\ndvi_map_16.png
# Saved: C:/maps/generated_maps\ndvi_map_17.png
# Saved: C:/maps/generated_maps\ndvi_map_18.png
# Saved: C:/maps/generated_maps\ndvi_map_19.png
# Saved: C:/maps/generated_maps\ndvi_map_20.png
# ...

# %%
import cv2
import numpy as np
import os

# Load the base image
image_path = "C:/maps/chennaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV for better color manipulation
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define the green color range (based on your base image)
lower_green = np.array([35, 40, 40])  
upper_green = np.array([85, 255, 255])

# Create a mask to detect green areas
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# Find contours (boundaries of green areas)
contours, _ = cv2.findContours(green_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# NDVI values for each map (20 stages)
ndvi_values = np.linspace(0.0840, 0.0559, 20)  # Smooth transition over 20 maps

# Output directory
output_dir = "C:/maps/generated_maps"
os.makedirs(output_dir, exist_ok=True)

# Generate maps with gradual loss of big green blobs with smooth blending
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    # Reduce green intensity based on NDVI
    factor = ndvi / max(ndvi_values)  
    adjusted_hsv[:, :, 1] = np.where(green_mask > 0, adjusted_hsv[:, :, 1] * factor, adjusted_hsv[:, :, 1])

    # **Shrink larger green blobs first (with soft blending)**
    removal_fraction = ((i + 1) / len(ndvi_values) * 0.4)  # Max 40% shrinkage over 20 stages
    num_contours_to_shrink = int(len(contours) * removal_fraction)

    if num_contours_to_shrink > 0:
        for j in range(num_contours_to_shrink):
            if j < len(contours):
                # Get a mask for this contour
                contour_mask = np.zeros_like(green_mask)
                cv2.drawContours(contour_mask, contours, j, (255), thickness=cv2.FILLED)

                # Find surrounding non-green pixels to blend with
                kernel_size = 5  # Slightly larger for better blending
                blurred_hsv = cv2.GaussianBlur(adjusted_hsv, (kernel_size, kernel_size), 0)

                # Replace green areas with a blend of surrounding pixels
                adjusted_hsv = np.where(contour_mask[..., None] > 0, blurred_hsv, adjusted_hsv)

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save the image
    output_path = os.path.join(output_dir, f"ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ All maps generated with soft blending of shrinking green blobs!")
# Out:
# Saved: C:/maps/generated_maps\ndvi_map_1.png
# Saved: C:/maps/generated_maps\ndvi_map_2.png
# Saved: C:/maps/generated_maps\ndvi_map_3.png
# Saved: C:/maps/generated_maps\ndvi_map_4.png
# Saved: C:/maps/generated_maps\ndvi_map_5.png
# Saved: C:/maps/generated_maps\ndvi_map_6.png
# Saved: C:/maps/generated_maps\ndvi_map_7.png
# Saved: C:/maps/generated_maps\ndvi_map_8.png
# Saved: C:/maps/generated_maps\ndvi_map_9.png
# Saved: C:/maps/generated_maps\ndvi_map_10.png
# Saved: C:/maps/generated_maps\ndvi_map_11.png
# Saved: C:/maps/generated_maps\ndvi_map_12.png
# Saved: C:/maps/generated_maps\ndvi_map_13.png
# Saved: C:/maps/generated_maps\ndvi_map_14.png
# Saved: C:/maps/generated_maps\ndvi_map_15.png
# Saved: C:/maps/generated_maps\ndvi_map_16.png
# Saved: C:/maps/generated_maps\ndvi_map_17.png
# Saved: C:/maps/generated_maps\ndvi_map_18.png
# Saved: C:/maps/generated_maps\ndvi_map_19.png
# Saved: C:/maps/generated_maps\ndvi_map_20.png
# ...

# %%
import cv2
import numpy as np
import os
image_path = "C:/maps/chennaimap.png"
base_image = cv2.imread(image_path)
if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)
lower_green = np.array([35, 40, 40])  
upper_green = np.array([85, 255, 255])
green_mask = cv2.inRange(hsv, lower_green, upper_green)
contours, _ = cv2.findContours(green_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
ndvi_values = [
    0.0840, 0.0746, 0.0717, 0.0676, 0.0648, 0.0623, 0.0602, 0.0585, 0.0571, 0.0559,
    0.0549, 0.0541, 0.0534, 0.0529, 0.0524, 0.0520, 0.0517, 0.0514, 0.0512, 0.0509
]
output_dir = "C:/maps/generated_maps"
os.makedirs(output_dir, exist_ok=True)
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    factor = ndvi / max(ndvi_values)  
    adjusted_hsv[:, :, 1] = np.where(green_mask > 0, adjusted_hsv[:, :, 1] * factor, adjusted_hsv[:, :, 1])
   
    removal_fraction = ((max(ndvi_values) - ndvi) / (max(ndvi_values) - min(ndvi_values))) * 0.5  
    num_contours_to_shrink = int(len(contours) * removal_fraction)
    if num_contours_to_shrink > 0:
        for j in range(num_contours_to_shrink):
            if j < len(contours):
               
                contour_mask = np.zeros_like(green_mask)
                cv2.drawContours(contour_mask, contours, j, (255), thickness=cv2.FILLED)
                kernel_size = 7  
                blurred_hsv = cv2.GaussianBlur(adjusted_hsv, (kernel_size, kernel_size), 0)

                
                adjusted_hsv = np.where(contour_mask[..., None] > 0, blurred_hsv, adjusted_hsv)
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)
   
    output_path = os.path.join(output_dir, f"ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ All 20 maps generated with smooth shrinking of green areas!")
# Out:
# Saved: C:/maps/generated_maps\ndvi_map_1.png
# Saved: C:/maps/generated_maps\ndvi_map_2.png
# Saved: C:/maps/generated_maps\ndvi_map_3.png
# Saved: C:/maps/generated_maps\ndvi_map_4.png
# Saved: C:/maps/generated_maps\ndvi_map_5.png
# Saved: C:/maps/generated_maps\ndvi_map_6.png
# Saved: C:/maps/generated_maps\ndvi_map_7.png
# Saved: C:/maps/generated_maps\ndvi_map_8.png
# Saved: C:/maps/generated_maps\ndvi_map_9.png
# Saved: C:/maps/generated_maps\ndvi_map_10.png
# Saved: C:/maps/generated_maps\ndvi_map_11.png
# Saved: C:/maps/generated_maps\ndvi_map_12.png
# Saved: C:/maps/generated_maps\ndvi_map_13.png
# Saved: C:/maps/generated_maps\ndvi_map_14.png
# Saved: C:/maps/generated_maps\ndvi_map_15.png
# Saved: C:/maps/generated_maps\ndvi_map_16.png
# Saved: C:/maps/generated_maps\ndvi_map_17.png
# Saved: C:/maps/generated_maps\ndvi_map_18.png
# Saved: C:/maps/generated_maps\ndvi_map_19.png
# Saved: C:/maps/generated_maps\ndvi_map_20.png
# ...

# %%
import cv2
import numpy as np
import os
import pandas as pd

# Load NDVI data for Shanghai
ndvi_df = pd.read_csv("C:/maps/datasets/ndvi_predictions_2025_2044.csv")
ndvi_values = ndvi_df["Predicted_NDVI"].tolist()
years = ndvi_df["Year"].tolist()

# Load Shanghai base map
image_path = "C:/maps/shanghaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Detect green regions
lower_green = np.array([35, 40, 40])
upper_green = np.array([85, 255, 255])
green_mask = cv2.inRange(hsv, lower_green, upper_green)
contours, _ = cv2.findContours(green_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Output directory
output_dir = "C:/maps/generated_maps2"
os.makedirs(output_dir, exist_ok=True)

# Generate images for each year
for i, (ndvi, year) in enumerate(zip(ndvi_values, years)):
    adjusted_hsv = hsv.copy()

    # Increase saturation for greenery
    factor = ndvi / max(ndvi_values)
    adjusted_hsv[:, :, 1] = np.where(
        green_mask > 0,
        adjusted_hsv[:, :, 1] * (0.5 + factor * 0.5),
        adjusted_hsv[:, :, 1]
    )

    # Expand green blobs
    expansion_fraction = ((ndvi - min(ndvi_values)) / (max(ndvi_values) - min(ndvi_values))) * 0.5
    num_contours_to_expand = int(len(contours) * expansion_fraction)

    if num_contours_to_expand > 0:
        for j in range(num_contours_to_expand):
            if j < len(contours):
                contour_mask = np.zeros_like(green_mask)
                cv2.drawContours(contour_mask, contours, j, (255), thickness=cv2.FILLED)

                # Dilate the green area
                kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
                dilated_mask = cv2.dilate(contour_mask, kernel, iterations=2)

                # Paint expanded green
                greenish_hsv = adjusted_hsv.copy()
                greenish_hsv[:, :, 0] = 60
                greenish_hsv[:, :, 1] = 255
                greenish_hsv[:, :, 2] = adjusted_hsv[:, :, 2]

                adjusted_hsv = np.where(dilated_mask[..., None] > 0, greenish_hsv, adjusted_hsv)

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save image
    output_path = os.path.join(output_dir, f"shanghai_ndvi_map_{year}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ All 20 Shanghai maps saved to C:/maps/generated_maps2!")
# Out:
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_2025.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_2026.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_2027.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_2028.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 54
#      51 cv2.drawContours(contour_mask, contours, j, (255), thickness=cv2.FILLED)
#      53 # Dilate the green area
# ---> 54 kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
#      55 dilated_mask = cv2.dilate(contour_mask, kernel, iterations=2)
#      57 # Paint expanded green
#
# KeyboardInterrupt:

# %%
import cv2
import numpy as np
import os
import pandas as pd

# Load the NDVI values from CSV
ndvi_df = pd.read_csv("C:/maps/datasets/ndvi_predictions_2025_2044.csv")
ndvi_values = ndvi_df["Predicted_NDVI"].tolist()

# Load the Shanghai base image
image_path = "C:/maps/shanghaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV for better color manipulation
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define the green color range (based on your base image)
lower_green = np.array([35, 40, 40])  
upper_green = np.array([85, 255, 255])

# Create a mask to detect green areas
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# Find contours (boundaries of green areas)
contours, _ = cv2.findContours(green_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Output directory
output_dir = "C:/maps/generated_maps2"
os.makedirs(output_dir, exist_ok=True)

# Generate maps with gradual **expansion** of green blobs based on NDVI values
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    # Increase green intensity based on NDVI
    factor = ndvi / max(ndvi_values)  
    adjusted_hsv[:, :, 1] = np.where(green_mask > 0, adjusted_hsv[:, :, 1] * (0.5 + factor * 0.5), adjusted_hsv[:, :, 1])

    # Expand green blobs gradually based on NDVI values
    expansion_fraction = ((ndvi - min(ndvi_values)) / (max(ndvi_values) - min(ndvi_values))) * 0.5  
    num_contours_to_expand = int(len(contours) * expansion_fraction)

    if num_contours_to_expand > 0:
        for j in range(num_contours_to_expand):
            if j < len(contours):
                # Get a mask for this contour
                contour_mask = np.zeros_like(green_mask)
                cv2.drawContours(contour_mask, contours, j, (255), thickness=cv2.FILLED)

                # Dilate the contour to simulate growth
                kernel_size = 7
                kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))
                dilated_mask = cv2.dilate(contour_mask, kernel, iterations=2)

                # Blend the grown area with surrounding greenish color
                blurred_hsv = cv2.GaussianBlur(adjusted_hsv, (kernel_size, kernel_size), 0)
                adjusted_hsv = np.where(dilated_mask[..., None] > 0, blurred_hsv, adjusted_hsv)

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save the image
    output_path = os.path.join(output_dir, f"shanghai_ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ All 20 Shanghai NDVI maps generated with increasing green areas!")
# Out:
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_1.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_2.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_3.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_4.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_5.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_6.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 60
#      58             # Blend the grown area with surrounding greenish color
#      59             blurred_hsv = cv2.GaussianBlur(adjusted_hsv, (kernel_size, kernel_size), 0)
# ---> 60             adjusted_hsv = np.where(dilated_mask[..., None] > 0, blurred_hsv, adjusted_hsv)
#      62 # Convert back to BGR
#      63 adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)
#
# KeyboardInterrupt:

# %%
import cv2
import numpy as np
import os
import pandas as pd

# Load NDVI values from CSV for Shanghai
ndvi_df = pd.read_csv("C:/maps/datasets/ndvi_predictions_2025_2044.csv")
ndvi_values = ndvi_df["Predicted_NDVI"].tolist()

# Load the base image of Shanghai
image_path = "C:/maps/shanghaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define green color range
lower_green = np.array([35, 40, 40])  
upper_green = np.array([85, 255, 255])

# Detect green areas
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# Find contours of green areas
contours, _ = cv2.findContours(green_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Output directory
output_dir = "C:/maps/generated_maps2"
os.makedirs(output_dir, exist_ok=True)

# Generate maps with increasing green enhancement
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    # Increase saturation in green areas based on NDVI
    factor = ndvi / max(ndvi_values)
    adjusted_hsv[:, :, 1] = np.where(
        green_mask > 0,
        adjusted_hsv[:, :, 1] * (0.5 + factor * 0.5),  # keeps natural look while increasing saturation
        adjusted_hsv[:, :, 1]
    )

    # Optional: highlight more green contours over time
    highlight_fraction = ((ndvi - min(ndvi_values)) / (max(ndvi_values) - min(ndvi_values))) * 0.5
    num_contours_to_enhance = int(len(contours) * highlight_fraction)

    if num_contours_to_enhance > 0:
        for j in range(num_contours_to_enhance):
            if j < len(contours):
                # Get mask for each contour
                contour_mask = np.zeros_like(green_mask)
                cv2.drawContours(contour_mask, contours, j, (255), thickness=cv2.FILLED)

                # Slightly increase brightness inside the contour
                adjusted_hsv[:, :, 2] = np.where(
                    contour_mask > 0,
                    np.clip(adjusted_hsv[:, :, 2] * 1.05, 0, 255),
                    adjusted_hsv[:, :, 2]
                )

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save the image
    output_path = os.path.join(output_dir, f"shanghai_ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ All 20 maps generated naturally with increasing greenery, no distortion!")
# Out:
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_1.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_2.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_3.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_4.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_5.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_6.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_7.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_8.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_9.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_10.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_11.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_12.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_13.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_14.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_15.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_16.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_17.png
# ...

# %%
import cv2
import numpy as np
import os
import pandas as pd

# Load NDVI values from CSV
ndvi_df = pd.read_csv("C:/maps/datasets/ndvi_predictions_2025_2044.csv")
ndvi_values = ndvi_df["Predicted_NDVI"].tolist()

# Load the base image
image_path = "C:/maps/shanghaimap.png"
base_image = cv2.imread(image_path)

if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define green range
lower_green = np.array([35, 40, 40])  
upper_green = np.array([85, 255, 255])

# Green mask
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# Find contours of green
contours, _ = cv2.findContours(green_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Output path
output_dir = "C:/maps/generated_maps2"
os.makedirs(output_dir, exist_ok=True)

# Max NDVI for normalization
max_ndvi = max(ndvi_values)

# Generate maps
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    # Strengthen green saturation significantly
    saturation_boost = (ndvi / max_ndvi) * 1.5  # ⬅️ increased multiplier for vivid green
    brightness_boost = (ndvi / max_ndvi) * 1.2  # ⬅️ slight brightness boost too

    # Apply boost only to green areas
    adjusted_hsv[:, :, 1] = np.where(
        green_mask > 0,
        np.clip(adjusted_hsv[:, :, 1] * saturation_boost, 0, 255),
        adjusted_hsv[:, :, 1]
    )
    adjusted_hsv[:, :, 2] = np.where(
        green_mask > 0,
        np.clip(adjusted_hsv[:, :, 2] * brightness_boost, 0, 255),
        adjusted_hsv[:, :, 2]
    )

    # Convert back to BGR
    adjusted_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save image
    output_path = os.path.join(output_dir, f"shanghai_ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_image)
    print(f"Saved: {output_path}")

print("✅ Done! All maps now show clearly increasing greenery 🌿")
# Out:
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_1.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_2.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_3.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_4.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_5.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_6.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_7.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_8.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_9.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_10.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_11.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_12.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_13.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_14.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_15.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_16.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_17.png
# ...

# %%
import cv2
import numpy as np
import os
import pandas as pd

# Load NDVI values from CSV
ndvi_df = pd.read_csv("C:/maps/datasets/ndvi_predictions_2025_2044.csv")
ndvi_values = ndvi_df["Predicted_NDVI"].tolist()

# Load base image
image_path = "C:/maps/shanghaimap.png"
base_image = cv2.imread(image_path)
if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Define green range
lower_green = np.array([35, 40, 40])
upper_green = np.array([85, 255, 255])

# Detect green mask
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# Find contours
contours, _ = cv2.findContours(green_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Output folder
output_dir = "C:/maps/generated_maps2"
os.makedirs(output_dir, exist_ok=True)

# Normalize
max_ndvi = max(ndvi_values)
min_ndvi = min(ndvi_values)

# Generate maps
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    # Compute boosts
    sat_boost = 1.5 + (ndvi - min_ndvi) / (max_ndvi - min_ndvi) * 1.5  # stronger range
    val_boost = 1.1 + (ndvi - min_ndvi) / (max_ndvi - min_ndvi) * 0.6  # brighter

    # Create a copy of green mask to slightly expand green area
    dilation_strength = int(((ndvi - min_ndvi) / (max_ndvi - min_ndvi)) * 5) + 1
    kernel = np.ones((dilation_strength, dilation_strength), np.uint8)
    expanded_mask = cv2.dilate(green_mask, kernel, iterations=1)

    # Apply saturation and value enhancement to expanded green area
    adjusted_hsv[:, :, 1] = np.where(
        expanded_mask > 0,
        np.clip(adjusted_hsv[:, :, 1] * sat_boost, 0, 255),
        adjusted_hsv[:, :, 1]
    )
    adjusted_hsv[:, :, 2] = np.where(
        expanded_mask > 0,
        np.clip(adjusted_hsv[:, :, 2] * val_boost, 0, 255),
        adjusted_hsv[:, :, 2]
    )

    # Convert back to BGR
    adjusted_bgr = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save
    output_path = os.path.join(output_dir, f"shanghai_ndvi_map_{i+1}.png")
    cv2.imwrite(output_path, adjusted_bgr)
    print(f"Saved: {output_path}")

print("✅ All maps saved! Green areas now look lush *and* grow slightly over the years 🌱🌳")
# Out:
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_1.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_2.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_3.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_4.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_5.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_6.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_7.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_8.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_9.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_10.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_11.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_12.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_13.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_14.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_15.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_16.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_17.png
# ...

# %%
import cv2
import numpy as np
import os
import pandas as pd

# Load NDVI values
ndvi_df = pd.read_csv("C:/maps/datasets/ndvi_predictions_2025_2044.csv")
ndvi_values = ndvi_df["Predicted_NDVI"].tolist()

# Load base image
image_path = "C:/maps/shanghaimap.png"
base_image = cv2.imread(image_path)
if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")

# Convert to HSV
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)

# Green range
lower_green = np.array([35, 40, 40])
upper_green = np.array([85, 255, 255])
green_mask = cv2.inRange(hsv, lower_green, upper_green)

# Output folder
output_dir = "C:/maps/generated_maps2"
os.makedirs(output_dir, exist_ok=True)

# Normalization
max_ndvi = max(ndvi_values)
min_ndvi = min(ndvi_values)

# Generate maps
for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()

    # Calculate how much to enhance color
    sat_boost = 1.2 + (ndvi - min_ndvi) / (max_ndvi - min_ndvi) * 1.0  # capped to keep natural
    val_boost = 1.0 + (ndvi - min_ndvi) / (max_ndvi - min_ndvi) * 0.4  # mild brightness boost

    # Slight dilation to expand greenery naturally
    dilation_size = 1 + int((ndvi - min_ndvi) / (max_ndvi - min_ndvi) * 1)  # max 2x2 kernel
    kernel = np.ones((dilation_size, dilation_size), np.uint8)
    expanded_mask = cv2.dilate(green_mask, kernel, iterations=1)

    # Apply green boost only where needed
    adjusted_hsv[:, :, 1] = np.where(
        expanded_mask > 0,
        np.clip(adjusted_hsv[:, :, 1] * sat_boost, 0, 255),
        adjusted_hsv[:, :, 1]
    )
    adjusted_hsv[:, :, 2] = np.where(
        expanded_mask > 0,
        np.clip(adjusted_hsv[:, :, 2] * val_boost, 0, 255),
        adjusted_hsv[:, :, 2]
    )

    # Back to BGR
    final_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

    # Save
    out_path = os.path.join(output_dir, f"shanghai_ndvi_map_{i+1}.png")
    cv2.imwrite(out_path, final_image)
    print(f"Saved: {out_path}")

print("✅ Done! Greenery now increases naturally, with slight area growth each year 🌱🌿")
# Out:
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_1.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_2.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_3.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_4.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_5.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_6.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_7.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_8.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_9.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_10.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_11.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_12.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_13.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_14.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_15.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_16.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_17.png
# ...

# %%
import cv2
import numpy as np
import os
import pandas as pd
ndvi_df = pd.read_csv("C:/maps/datasets/ndvi_predictions_2025_2044.csv")
ndvi_values = ndvi_df["Predicted_NDVI"].tolist()
ndvi_values.sort()  
image_path = "C:/maps/shanghaimap.png"
base_image = cv2.imread(image_path)
if base_image is None:
    raise FileNotFoundError("Image not found at the specified path.")
hsv = cv2.cvtColor(base_image, cv2.COLOR_BGR2HSV)
lower_green = np.array([35, 40, 40])
upper_green = np.array([85, 255, 255])
green_mask = cv2.inRange(hsv, lower_green, upper_green)

output_dir = "C:/maps/generated_maps2"
os.makedirs(output_dir, exist_ok=True)

max_ndvi = max(ndvi_values)

for i, ndvi in enumerate(ndvi_values):
    adjusted_hsv = hsv.copy()
   
    sat_factor = (ndvi / max_ndvi) * 1.6   
    val_factor = (ndvi / max_ndvi) * 1.3   


    adjusted_hsv[:, :, 1] = np.where(
        green_mask > 0,
        np.clip(adjusted_hsv[:, :, 1] * sat_factor, 0, 255),
        adjusted_hsv[:, :, 1]
    )
    adjusted_hsv[:, :, 2] = np.where(
        green_mask > 0,
        np.clip(adjusted_hsv[:, :, 2] * val_factor, 0, 255),
        adjusted_hsv[:, :, 2]
    )

   
    final_image = cv2.cvtColor(adjusted_hsv, cv2.COLOR_HSV2BGR)

   
    out_path = os.path.join(output_dir, f"shanghai_ndvi_map_{i+1}.png")
    cv2.imwrite(out_path, final_image)
    print(f"Saved: {out_path}")

print("✅ All maps generated with smooth, natural increase in greenery 🌿")
# Out:
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_1.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_2.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_3.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_4.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_5.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_6.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_7.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_8.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_9.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_10.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_11.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_12.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_13.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_14.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_15.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_16.png
# Saved: C:/maps/generated_maps2\shanghai_ndvi_map_17.png
# ...
